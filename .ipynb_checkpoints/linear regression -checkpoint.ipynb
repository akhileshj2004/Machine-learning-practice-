# %% [markdown]
# # METHOD OF LEAST SQUARES

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\anaconda3\headbrain.csv")
data
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
plt.rcParams['figure.figsize'] = (12.0,9.0)

# %%
x = data['Head Size(cm^3)']
y = data['Brain Weight(grams)']

# %%
plt.scatter(x,y)
plt.title('HEADBRAIN DATA LINEAR REGRESSION')
plt.xlabel('Head size')
plt.ylabel('Brain Weight')
# Out:
# Text(0, 0.5, 'Brain Weight')

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

num=0
den=0
for  i in range(len(x)):
    num += (x[i] - x_mean)*(y[i] - y_mean)
    den += (x[i] - x_mean)**2
m = num / den
c =y_mean - m*x_mean


print(f' M = : {m}')
print(f' C = : {c}')
# Out:
#  M = : 0.26342933948939945
#  C = : 325.57342104944223

# %%
y_pred = m*x+c
plt.scatter(x,y)
plt.plot ([min(x), max(x)], [min(y_pred),max(y_pred)], color='red')
plt.title('HEADBRAIN DATA LINEAR REGRESSION')
plt.xlabel('Head size')
plt.ylabel('Brain Weight')
plt.show()

# %% [markdown]
# # BATCH GRADIENT DESCENT

# %%
from sklearn.metrics import mean_squared_error
# BUILDING THE MODEL 

m = 0
c = 0

l = 0.0001 # learning rate 

epochs = 2000 #the number of iterations to perform gradient descent 

n =  float(len(x)) # number of elements in x 

#performiing gradient decent 
for  i in range(epochs):
    y_pred = m * x + c #the current predicted value of y 
    d_m =  (-1/n) * sum(x *(y - y_pred)) #derivative wrt m 
    d_c =  (-1/n) * sum(x *(y - y_pred))

print(f' M = : {m}')
print(f' C = : {c}')

# %%
#making predictions 
y_pred = m*x+c
plt.scatter(x,y)
plt.plot ([min(x), max(x)], [min(y_pred),max(y_pred)], color='red')
plt.title('HEADBRAIN DATA LINEAR REGRESSION')
plt.xlabel('Head size')
plt.ylabel('Brain Weight')
plt.show()
