# %% [markdown]
# # BATCH GRADIENT DESCENT

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\anaconda3\example_data.csv")
data
# Out:
#      5.1101    17.592
# 0    5.5277   9.13020
# 1    8.5186  13.66200
# 2    7.0032  11.85400
# 3    5.8598   6.82330
# 4    8.3829  11.88600
# ..      ...       ...
# 91   5.8707   7.20290
# 92   5.3054   1.98690
# 93   8.2934   0.14454
# 94  13.3940   9.05510
# 95   5.4369   0.61705
#
# [96 rows x 2 columns]

# %%
plt.rcParams['figure.figsize'] = (12.0,9.0)

# %%
x = data.iloc[:,0]
y = data.iloc[:,1]
plt.scatter(x,y)
plt.title('data')
# Out:
# Text(0.5, 1.0, 'data')

# %%
###  APPLY NORMALISATION IF NEEDED 
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

#Assuming 'data' is your DataFrame
#Replace column indices (0 and 1) with actual column names or use iloc directly

#List of column indices you want to normalize
columns_to_normalize = [0, 1]

#Initialize MinMaxScaler
scaler = MinMaxScaler()

#Normalize each column by index
for col_index in columns_to_normalize:
    Normal = data.iloc[:, col_index].values.reshape(-1, 1)
    data.iloc[:, col_index] = scaler.fit_transform(Normal)
    
    # Print the max and min values after normalization
    print(f"The Max Value of column {col_index} is: {data.iloc[:, col_index].max()}")
    print(f"The Min Value of column {col_index} is: {data.iloc[:, col_index].min()}")
    
    print(f"Normalized - column {col_index}")
    print(data.iloc[:, col_index])
# Out:
# The Max Value of column 0 is: 1.0
# The Min Value of column 0 is: 0.0
# Normalized - column 0
# 0     0.029157
# 1     0.203288
# 2     0.115061
# 3     0.048492
# 4     0.195388
#         ...
# 91    0.049126
# 92    0.016214
# 93    0.190177
# 94    0.487136
# 95    0.023870
# Name: 5.1101, Length: 96, dtype: float64
# The Max Value of column 1 is: 1.0
# The Min Value of column 1 is: 0.0
# Normalized - column 1
# 0     0.440250
# 1     0.609173
# 2     0.541780
# 3     0.354261
# 4     0.542972
#         ...
# 91    0.368410
# 92    0.173984
# 93    0.105311
# 94    0.437451
# 95    0.122923
# Name: 17.592, Length: 96, dtype: float64

# %% [markdown]
# ## LEARNINIG RATE 0.0001

# %%
from sklearn.metrics import mean_squared_error
# Initialize variables
m = 0  # initial slope
c = 0  # initial intercept
l = 0.0001  # learning rate
epochs = 2000  # number of iterations
n = float(len(x))  # number of elements in x

# Lists to store values for plotting
am_values = []
ac_values = []
amse_values = []

# Variables to track the minimum MSE and corresponding epoch, m, and c values
min_mse = float('inf')
best_epoch = 0

best_m = 0
best_c = 0

# Perform gradient descent
for i in range(epochs):
    y_pred = m * x + c  # predicted y values
    d_m = (-1/n) * sum(x * (y - y_pred))  # derivative wrt m
    d_c = (-1/n) * sum(y - y_pred)  # derivative wrt c
    m = m - l * d_m  # update m
    c = c - l * d_c  # update c
    
    mse = mean_squared_error(y, y_pred)
    
    
    # Store the values for plotting
    am_values.append(m)
    ac_values.append(c)
    amse_values.append(mse)

    
    print('epoch= ',i)
    print(f'M = {m}')
    print(f'C = {c}')
    print(f'Mean Squared Error: {mse}')
# Out:
# epoch=  0
# M = 9.628031384856324e-06
# C = 3.1301264644378756e-05
# Mean Squared Error: 0.13814382788941715
# epoch=  1
# M = 1.925541213857496e-05
# C = 6.259922386948015e-05
# Mean Squared Error: 0.13812237962356447
# epoch=  2
# M = 2.8882142326792495e-05
# C = 9.389387801769181e-05
# Mean Squared Error: 0.13810093574638185
# epoch=  3
# M = 3.850822201513873e-05
# C = 0.000125185227431366
# Mean Squared Error: 0.13807949625696148
# epoch=  4
# M = 4.813365126923668e-05
# C = 0.00015647327245281944
# Mean Squared Error: 0.1380580611543958
# epoch=  5
# M = 5.7758430154702587e-05
# C = 0.00018775801342433353
# Mean Squared Error: 0.13803663043777745
# epoch=  6
# M = 6.73825587371459e-05
# C = 0.0002190394506881542
# Mean Squared Error: 0.13801520410619908
# epoch=  7
# M = 7.70060370821693e-05
# C = 0.0002503175845864919
# Mean Squared Error: 0.13799378215875371
# epoch=  8
# M = 8.662886525536867e-05
# C = 0.00028159241546152184
# Mean Squared Error: 0.13797236459453455
# ...

# %%
# Plotting Mean Squared Error over epochs
plt.figure(figsize=(10, 6))
plt.plot(amse_values, label="Mean Squared Error")
plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error")
plt.title("MSE vs Epochs for Gradient Descent")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Check if the current mse is the smallest one so far
if mse < min_mse:
        min_mse = mse
        best_epoch = i
        best_m = m
        best_c = c
        # Print the results
        print(f'The epoch with the least MSE is: {best_epoch}')
        print(f'Best M = {best_m}')
        print(f'Best C = {best_c}')
        print(f'Least Mean Squared Error: {min_mse}')
# Out:
# The epoch with the least MSE is: 1999
# Best M = 0.018038506187370077
# Best C = 0.056428217194968405
# Least Mean Squared Error: 0.10294116587731661

# %%
y_pred = m*x+c
plt.scatter(x,y)
plt.plot ([min(x), max(x)], [min(y_pred),max(y_pred)], color='red')
plt.title('PLOT A LINE ')
plt.xlabel(' X ')
plt.ylabel(' Y ')
plt.show()

# %% [markdown]
# ## Learning rate comparison

# %% [markdown]
# ## learning rate = 0.0100

# %%
# Initialize variables
m = 0  # initial slope
c = 0  # initial intercept
l = 0.0100  # learning rate
epochs = 2000  # number of iterations
n = float(len(x))  # number of elements in x

# Lists to store values for plotting
bm_values = []
bc_values = []
bmse_values = []

# Variables to track the minimum MSE and corresponding epoch, m, and c values
min_mse = float('inf')
best_epoch = 0

best_m = 0
best_c = 0

# Perform gradient descent
for i in range(epochs):
    y_pred = m * x + c  # predicted y values
    d_m = (-1/n) * sum(x * (y - y_pred))  # derivative wrt m
    d_c = (-1/n) * sum(y - y_pred)  # derivative wrt c
    m = m - l * d_m  # update m
    c = c - l * d_c  # update c
    
    mse = mean_squared_error(y, y_pred)
    
    
    # Store the values for plotting
    bm_values.append(m)
    bc_values.append(c)
    bmse_values.append(mse)

    
    print('epoch= ',i)
    print(f'M = {m}')
    print(f'C = {c}')
    print(f'Mean Squared Error: {mse}')
# Out:
# epoch=  0
# M = 0.0009628031384856324
# C = 0.0031301264644378757
# Mean Squared Error: 0.13814382788941715
# epoch=  1
# M = 0.001919099965594392
# C = 0.006227198736102082
# Mean Squared Error: 0.13600986438610424
# epoch=  2
# M = 0.0028689561179121815
# C = 0.009291559202640182
# Mean Squared Error: 0.13391933933276223
# epoch=  3
# M = 0.003812436553611189
# C = 0.012323546708321979
# Mean Squared Error: 0.1318713588204756
# epoch=  4
# M = 0.004749605559470087
# C = 0.015323496590708438
# Mean Squared Error: 0.129865047345456
# epoch=  5
# M = 0.005680526757821583
# C = 0.018291740716941157
# Mean Squared Error: 0.1278995474300809
# epoch=  6
# M = 0.00660526311342807
# C = 0.02122860751965627
# Mean Squared Error: 0.1259740192517346
# epoch=  7
# M = 0.007523876940286124
# C = 0.02413442203252672
# Mean Squared Error: 0.12408764027929202
# epoch=  8
# M = 0.008436429908360589
# C = 0.027009505925436706
# Mean Squared Error: 0.12223960491708656
# epoch=  9
# ...

# %%
# Plotting Mean Squared Error over epochs
plt.figure(figsize=(10, 6))

plt.plot(bmse_values, label="alpha = 0.0100")

plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error")
plt.title("MSE vs Epochs for Gradient Descent")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## learninig rate = 0.900

# %%
# Initialize variables
m = 0  # initial slope
c = 0  # initial intercept
l = 0.900  # learning rate
epochs = 2000  # number of iterations
n = float(len(x))  # number of elements in x

# Lists to store values for plotting
cm_values = []
cc_values = []
cmse_values = []

# Variables to track the minimum MSE and corresponding epoch, m, and c values
min_mse = float('inf')
best_epoch = 0

best_m = 0
best_c = 0

# Perform gradient descent
for i in range(epochs):
    y_pred = m * x + c  # predicted y values
    d_m = (-1/n) * sum(x * (y - y_pred))  # derivative wrt m
    d_c = (-1/n) * sum(y - y_pred)  # derivative wrt c
    m = m - l * d_m  # update m
    c = c - l * d_c  # update c
    
    mse = mean_squared_error(y, y_pred)
    
    
    # Store the values for plotting
    cm_values.append(m)
    cc_values.append(c)
    cmse_values.append(mse)

    
    print('epoch= ',i)
    print(f'M = {m}')
    print(f'C = {c}')
    print(f'Mean Squared Error: {mse}')
# Out:
# epoch=  0
# M = 0.08665228246370692
# C = 0.2817113817994088
# Mean Squared Error: 0.13814382788941715
# epoch=  1
# M = 0.12060344277475096
# C = 0.2956838021320797
# Mean Squared Error: 0.03397932115192341
# epoch=  2
# M = 0.14970255205497662
# C = 0.29151785607453273
# Mean Squared Error: 0.031448598939588644
# epoch=  3
# M = 0.17728795774934933
# C = 0.28633312345175754
# Mean Squared Error: 0.02957257302989297
# epoch=  4
# M = 0.20364084739176866
# C = 0.281294545455702
# Mean Squared Error: 0.027860445372774614
# epoch=  5
# M = 0.228830299588733
# C = 0.2764725412223925
# Mean Squared Error: 0.02629603097382539
# epoch=  6
# M = 0.2529086402848128
# C = 0.27186283354474555
# Mean Squared Error: 0.024866577119723985
# epoch=  7
# M = 0.27592494684743046
# C = 0.2674564206483529
# Mean Squared Error: 0.02356044085095803
# epoch=  8
# M = 0.297926067422284
# C = 0.26324436060923345
# Mean Squared Error: 0.022366983679906263
# epoch=  9
# M = 0.3189567793825376
# ...

# %%
# Plotting Mean Squared Error over epochs
plt.figure(figsize=(10, 6))

plt.plot(cmse_values, label="alpha = 0.0100")

plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error")
plt.title("MSE vs Epochs for Gradient Descent")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## learning rate =0.00001

# %%
# Initialize variables
m = 0  # initial slope
c = 0  # initial intercept
l = 0.900  # learning rate
epochs = 2000  # number of iterations
n = float(len(x))  # number of elements in x

# Lists to store values for plotting
dm_values = []
dc_values = []
dmse_values = []

# Variables to track the minimum MSE and corresponding epoch, m, and c values
min_mse = float('inf')
best_epoch = 0

best_m = 0
best_c = 0

# Perform gradient descent
for i in range(epochs):
    y_pred = m * x + c  # predicted y values
    d_m = (-1/n) * sum(x * (y - y_pred))  # derivative wrt m
    d_c = (-1/n) * sum(y - y_pred)  # derivative wrt c
    m = m - l * d_m  # update m
    c = c - l * d_c  # update c
    
    mse = mean_squared_error(y, y_pred)
    
    
    # Store the values for plotting
    dm_values.append(m)
    dc_values.append(c)
    dmse_values.append(mse)

    
    print('epoch= ',i)
    print(f'M = {m}')
    print(f'C = {c}')
    print(f'Mean Squared Error: {mse}')
# Out:
# epoch=  0
# M = 0.08665228246370692
# C = 0.2817113817994088
# Mean Squared Error: 0.13814382788941715
# epoch=  1
# M = 0.12060344277475096
# C = 0.2956838021320797
# Mean Squared Error: 0.03397932115192341
# epoch=  2
# M = 0.14970255205497662
# C = 0.29151785607453273
# Mean Squared Error: 0.031448598939588644
# epoch=  3
# M = 0.17728795774934933
# C = 0.28633312345175754
# Mean Squared Error: 0.02957257302989297
# epoch=  4
# M = 0.20364084739176866
# C = 0.281294545455702
# Mean Squared Error: 0.027860445372774614
# epoch=  5
# M = 0.228830299588733
# C = 0.2764725412223925
# Mean Squared Error: 0.02629603097382539
# epoch=  6
# M = 0.2529086402848128
# C = 0.27186283354474555
# Mean Squared Error: 0.024866577119723985
# epoch=  7
# M = 0.27592494684743046
# C = 0.2674564206483529
# Mean Squared Error: 0.02356044085095803
# epoch=  8
# M = 0.297926067422284
# C = 0.26324436060923345
# Mean Squared Error: 0.022366983679906263
# epoch=  9
# M = 0.3189567793825376
# ...

# %%
# Plotting Mean Squared Error over epochs
plt.figure(figsize=(10, 6))

plt.plot(cmse_values, label="alpha = 0.0100")

plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error")
plt.title("MSE vs Epochs for Gradient Descent")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 9, 11, 13])

# Learning rates to test
learning_rates = [0.001, 0.0005, 0.0001]

# Number of iterations
epochs = 2000

# Plotting MSE for different learning rates
plt.figure(figsize=(12, 8))

for lr in learning_rates:
    # Initialize variables
    m = 0
    c = 0
    n = float(len(x))
    
    # List to store MSE values
    mse_values = []
    
    # Perform gradient descent
    for i in range(epochs):
        y_pred = m * x + c
        d_m = (-1/n) * sum(x * (y - y_pred))
        d_c = (-1/n) * sum(y - y_pred)
        m = m - lr * d_m
        c = c - lr * d_c
        
        mse = mean_squared_error(y, y_pred)
        mse_values.append(mse)
    
    # Plot the MSE for the current learning rate
    plt.plot(mse_values, label=f"Learning Rate = {lr}")

# Add labels and title
plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error")
plt.title("MSE vs Epochs for Different Learning Rates")
plt.legend()
plt.grid(True)
plt.show()

# %%
# plot for different learning rates in given algos 
plt.plot(amse_values, label="alpha = 0.0001")
plt.plot(bmse_values, label="alpha = 0.0100")
plt.plot(cmse_values, label="alpha = 0.0900")
plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error")
plt.title("MSE vs Epochs for Different Learning Rates")
plt.legend()
plt.grid(True)
plt.show()
